# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("heart.csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  target
# 0      52    1   0       125   212    0        1      168      0      1.0      2   2     3       0
# 1      53    1   0       140   203    1        0      155      1      3.1      0   0     3       0
# 2      70    1   0       145   174    0        1      125      1      2.6      0   0     3       0
# 3      61    1   0       148   203    0        1      161      0      0.0      2   1     3       0
# 4      62    0   0       138   294    1        1      106      0      1.9      1   3     2       0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...    ...  ..   ...     ...
# 1020   59    1   1       140   221    0        1      164      1      0.0      2   0     2       1
# 1021   60    1   0       125   258    0        0      141      1      2.8      1   1     3       0
# 1022   47    1   0       110   275    0        0      118      1      1.0      1   1     2       0
# 1023   50    0   0       110   254    0        0      159      0      0.0      2   0     2       1
# 1024   54    1   0       120   188    0        1      113      0      1.4      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# ## preprocessing ##

# %%
df.dropna(inplace=True)

lable_encoder={}
for col in df.select_dtypes(include=['object']).columns:
    le=LableEncoder()
    df[col]=le.fit_transform(df[col])
    lable_encoder[col]=le

# %% [markdown]
# ## spliting dataset into training and testing sets##

# %%
x=df.drop(columns=['target'])
y=df['target']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Standardize features ##

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# ## Trainn and Evaluate SVM Models ##

# %%
svm_linear=SVC(kernel='linear',C=1)
svm_linear.fit(x_train,y_train)
y_pred_linear=svm_linear.predict(x_test)


svm_ploy=SVC(kernel='poly',C=1,degree=3)
svm_ploy.fit(x_train,y_train)
y_pred_poly=svm_ploy.predict(x_test)


svm_rbf=SVC(kernel='rbf',C=1,gamma='scale')
svm_rbf.fit(x_train,y_train)
y_pred_rbf=svm_rbf.predict(x_test)

# %% [markdown]
# ## Evaluate Model Performance ##

# %%
print(f'Linear Kernel Accuracy: {accuracy_score(y_test,y_pred_linear):.2f}')
print(f'polynomial Kernel Accuracy: {accuracy_score(y_test,y_pred_poly):.2f}')
print(f'RBF  Kernel Accuracy: {accuracy_score(y_test,y_pred_rbf):.2f}')
# Out:
# Linear Kernel Accuracy: 0.81
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 print(f'Linear Kernel Accuracy: {accuracy_score(y_test,y_pred_linear):.2f}')
# ----> 2 print(f'polynomial Kernel Accuracy: {accuracy_score(y_test,y_pred_poly):.2f}')
#       3 print(f'RBF  Kernel Accuracy: {accuracy_score(y_test,y_pred_rbf):.2f}')
#
# NameError: name 'y_pred_poly' is not defined
